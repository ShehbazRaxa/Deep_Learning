# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/Copy of sonar data.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
dataset.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032  R
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044  R
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078  R
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117  R
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094  R
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  ...  0.0057  0.0027  0.0051  0.0062  R
#
# [5 rows x 61 columns]

# %%
dataset.value_counts()
# Out:
# 0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999  0.5078  0.4797  0.5783  0.5071  0.4328  0.5550  0.6711  0.6415  0.7104  0.8080  0.6791  0.3857  0.1307  0.2604  0.5121  0.7547  0.8537  0.8507  0.6692  0.6097  0.4943  0.2744  0.0510  0.2834  0.2825  0.4256  0.2641  0.1386  0.1051  0.1343  0.0383  0.0324  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032  R
# 0.1371  0.1226  0.1385  0.1484  0.1776  0.1428  0.1773  0.2161  0.1630  0.2067  0.4257  0.5484  0.7131  0.7003  0.6777  0.7939  0.9382  0.8925  0.9146  0.7832  0.7960  0.7983  0.7716  0.6615  0.4860  0.5572  0.4697  0.5640  0.4517  0.3369  0.2684  0.2339  0.3052  0.3016  0.2753  0.1041  0.1757  0.3156  0.3603  0.2736  0.1301  0.2458  0.3404  0.1753  0.0679  0.1062  0.0643  0.0532  0.0531  0.0272  0.0171  0.0118  0.0129  0.0344  0.0065  0.0067  0.0022  0.0079  0.0146  0.0051  M    1
# ...

# %%
dataset.shape
# Out:
# (207, 61)

# %%
dataset.R.value_counts()
# Out:
# M    111
# R     96
# Name: R, dtype: int64

# %%
dic = {'M':0 , 'R':1}

# %%
dataset.replace({'R':dic},inplace=True)

# %%
dataset.R.value_counts()
# Out:
# 0    111
# 1     96
# Name: R, dtype: int64

# %%
x = dataset.drop('R',axis=1)
y = dataset['R']

# %%
x
# Out:
#      0.0200  0.0371  0.0428  0.0207  ...  0.0180  0.0084  0.0090  0.0032
# 0    0.0453  0.0523  0.0843  0.0689  ...  0.0140  0.0049  0.0052  0.0044
# 1    0.0262  0.0582  0.1099  0.1083  ...  0.0316  0.0164  0.0095  0.0078
# 2    0.0100  0.0171  0.0623  0.0205  ...  0.0050  0.0044  0.0040  0.0117
# 3    0.0762  0.0666  0.0481  0.0394  ...  0.0072  0.0048  0.0107  0.0094
# 4    0.0286  0.0453  0.0277  0.0174  ...  0.0057  0.0027  0.0051  0.0062
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
# 203  0.0323  0.0101  0.0298  0.0564  ...  0.0034  0.0032  0.0062  0.0067
# 204  0.0522  0.0437  0.0180  0.0292  ...  0.0140  0.0138  0.0077  0.0031
# 205  0.0303  0.0353  0.0490  0.0608  ...  0.0034  0.0079  0.0036  0.0048
# 206  0.0260  0.0363  0.0136  0.0272  ...  0.0040  0.0036  0.0061  0.0115
#
# [207 rows x 60 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 202    0
# 203    0
# 204    0
# 205    0
# 206    0
# Name: R, Length: 207, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_label,test_label = train_test_split(x,y,test_size=0.15,stratify=y)

# %%
from tensorflow.keras import models
from tensorflow.keras.layers import *

# %%
model = models.Sequential()
model.add(Dense(128, activation='relu',input_shape=(train_data.shape[1],)))
model.add(Dense(16, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.fit(train_data, train_label,epochs=50)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 1s 3ms/step - loss: 0.6911 - acc: 0.5371
# Epoch 2/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6626 - acc: 0.6400
# Epoch 3/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6477 - acc: 0.6686
# Epoch 4/50
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6269 - acc: 0.6743
# Epoch 5/50
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6120 - acc: 0.7257
# Epoch 6/50
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5961 - acc: 0.7314
# Epoch 7/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5820 - acc: 0.7543
# Epoch 8/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5662 - acc: 0.7429
# Epoch 9/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5519 - acc: 0.7543
# Epoch 10/50
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5396 - acc: 0.8000
# Epoch 11/50
# ...

# %%
model.evaluate(test_data,test_label)
# Out:
# 1/1 [==============================] - 0s 123ms/step - loss: 0.2680 - acc: 0.9062
# [0.2680422067642212, 0.90625]

# %%
model.save('Sonar_Rock_and_Mine_Classification.h5')
